# %% [markdown]
# ```text
# Dilation = grow white objects
# Erosion = shrink white objects
# Opening = erosion → dilation
# Closing = dilation → erosion
# Kernel = neighborhood used for the operation

# %% [markdown]
# Can take code from sprint 04 Image processing - topic 03 Scaling_Rotating_Shifting_Edge Detection file
#
# OR refer the below code

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread(r'C:\Users\Hp\Pictures\OpenCVSamples\cat.webp', 0)

kernel = np.ones((5, 5), np.uint8)

img_dilation = cv2.dilate(img, kernel, iterations=1)
img_erosion = cv2.erode(img,kernel,iterations=1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_dilation, cmap='gray')
plt.title("After Dilation")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(img_erosion, cmap='gray')
plt.title("After Erosion")
plt.axis('off')

plt.show()
